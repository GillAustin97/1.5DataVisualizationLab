# %% [markdown]
# # Lab Instructions
#
# Find a dataset that interests you. I'd recommend starting on [Kaggle](https://www.kaggle.com/). Read through all of the material about the dataset and download a .CSV file.
#
# 1. Write a short summary of the data.  Where did it come from?  How was it collected?  What are the features in the data?  Why is this dataset interesting to you?
#
# 2. Identify 5 interesting questions about your data that you can answer using Pandas methods.
#
# 3. Answer those questions!  You may use any method you want (including LLMs) to help you write your code; however, you should use Pandas to find the answers.  LLMs will not always write code in this way without specific instruction.
#
# 4. Write the answer to your question in a text box underneath the code you used to calculate the answer.

# %% [markdown]
# **Summary:**
# ```
# This data was collected by sales figures, release/discontinuation years including generational classifications
# for each of the consoles. It came from links that they provided gaming/console history. Including wikipedia,
# sales reports and archives.
#
# ```
#
# **Features:**
#
# * Console names
# * Type
# * Company
# * Gen
# * Gen Years
# * Released Year
# * Generation
# * Discontinuation Year
# * Units Solds
# * Remarks
# * Link to gif
#
# **Why is it Intersting?:**
#
# ```
# It is interesting because you can see the evolution of video game consoles being sold by the millions starting from the 1970s to today.
# It shows all sales data much as they can get showing company dominances in each year. You can see who ahd the best console during that time.
# ```
# **1-5 questions:**
# * What company is the most successful this year?
# * What company was the most successful in the first year of console wars?
# * How long does consoles last before being discontinued?
# * Does newer consoles sell more than older consoles?
# * What is the most popular console this year?

# %%
import pandas as pd

df = pd.read_csv("Console_Data.csv")

df.head(25)
# Out:
#                      Console Name  Type    Company      Gen     Gen Years  \
# 0                Magnavox Odyssey  Home   Magnavox  1st Gen     1972-1978
# 1                       Home Pong  Home      Atari  1st Gen     1972-1978
# 2                      Atari 2600  Home      Atari  2nd Gen     1978-1982
# 3              Magnavox Odyssey 2  Home   Magnavox  2nd Gen     1978-1982
# 4                   Intellivision  Home     Mattel  2nd Gen     1978-1982
# 5                 Atari 5200/7800  Home      Atari  3rd Gen     1982-1988
# 6   Nintendo Entertainment System  Home   Nintendo  3rd Gen     1982-1988
# 7              Sega Master System  Home       Sega  3rd Gen     1982-1988
# 8                    Sega Genesis  Home       Sega  4th Gen     1988-1994
# 9                  Super Nintendo  Home   Nintendo  4th Gen     1988-1994
# 10                    PlayStation  Home       Sony  5th Gen     1994-1998
# 11                    Sega Saturn  Home       Sega  5th Gen     1994-1998
# ...

# %%
import pandas as pd

df = pd.read_csv("Console_Data.csv")

df["Company"].value_counts().plot(kind="bar", title="Most Successful Companies")
# Out:
# <Axes: title={'center': 'Most Successful Companies'}, xlabel='Company'>

# %% [markdown]
# * What company is the most successful this year?
#   **Nintendo was the most successful, But this might be overall**

# %%
import pandas as pd

df = pd.read_csv("Console_Data.csv")

df[df["Generation"] == 1]["Company"].value_counts().plot(
    kind="bar",
    title="Most Successful Company in the First Generation"
)
# Out:
# <Axes: title={'center': 'Most Successful Company in the First Generation'}, xlabel='Company'>

# %% [markdown]
#
# * What company was the most successful in the first year of console wars?
#   **Looks like there is a tie for the first year but maybe its cause first gens to try both of them out caused it to be close**

# %%
import pandas as pd

df = pd.read_csv("Console_Data.csv")

df["Discontinuation Year"] = pd.to_numeric(df["Discontinuation Year"], errors="coerce")

(df["Discontinuation Year"] - df["Released Year"]).plot(
    kind="hist",
    title="Console Lifespan (Years)"
)
# Out:
# <Axes: title={'center': 'Console Lifespan (Years)'}, ylabel='Frequency'>

# %% [markdown]
# * How long does consoles last before being discontinued?
#   **^ years seems to be how long consoles last before discontinued**

# %%
import pandas as pd

df = pd.read_csv("Console_Data.csv")

df.groupby("Generation")["Units sold (million)"].mean().plot(kind="line",
    title="Average Units Sold by Console Generation"
)
# Out:
# <Axes: title={'center': 'Average Units Sold by Console Generation'}, xlabel='Generation'>

# %% [markdown]
# * Does newer consoles sell more than older consoles?
#   **Newer consoles sell more than the older consoles currently, you can see that the 6-9th gen sells more than the older gens**

# %%
import pandas as pd

df = pd.read_csv("Console_Data.csv")

df.plot(
    kind="bar",
    x="Console Name",
    y="Units sold (million)",
    title="Most Popular Console"
)
# Out:
# <Axes: title={'center': 'Most Popular Console'}, xlabel='Console Name'>

# %% [markdown]
# * What is the most popular console this year?
#   **Playstation 2 still seems to be the winner!**
